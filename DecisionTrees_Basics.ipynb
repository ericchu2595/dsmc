# %% [markdown]
# <a href="https://colab.research.google.com/github/ericchu2595/dsmc/blob/master/DecisionTrees_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# # Get the Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Regression/Logistic Regression/data/kyphosis.csv')

# %%
df.head(10)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5
# 3   absent    2       5      1
# 4   absent    1       4     15
# 5   absent    1       2     16
# 6   absent   61       2     17
# 7   absent   37       3     16
# 8   absent  113       2     16
# 9  present   59       6     12

# %% [markdown]
# EDA

# %%
sns.pairplot(df, hue='Kyphosis', palette='Set1')
